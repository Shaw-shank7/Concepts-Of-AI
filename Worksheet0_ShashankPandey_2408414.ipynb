# %%
#Dynamic Programming
#Task 1: Coin Change Problem
def min_coins(coins, amount):
    """
    Finds the minimum number of coins needed to make up a given amount using dynamic programming.
    This function solves the coin change problem by determining the fewest number of coins
    from a given set of coin denominations that sum up to a target amount. The solution uses
    dynamic programming (tabulation) to iteratively build up the minimum number of coins required
    for each amount.

    Parameters:
    coins (list of int): A list of coin denominations available for making change.
                         Each coin denomination is a positive integer.
    amount (int): The target amount for which we need to find the minimum number of coins.
                  It must be a non-negative integer.

    Returns:
    int: The minimum number of coins required to make the given amount.
         If it is not possible to make the amount with the given coins, returns -1.
    """
    # Initialize DP table with 'inf' for all amounts except 0
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0  # Base case: 0


    for coin in coins:
        for x in range(coin, amount + 1):
            dp[x] = min(dp[x], dp[x - coin] + 1)


    return dp[amount] if dp[amount] != float('inf') else -1

# Test the function
coins = [1, 2, 5]
amount = 11
result = min_coins(coins, amount)
print(f"Minimum coins needed to make amount {amount}: {result}")
# Out:
# Minimum coins needed to make amount 11: 3

# %%
#Task 2: Longest Common Subsequence(LCS)
def longest_common_subsequence(s1, s2):
    """
    Computes the length of the Longest Common Subsequence (LCS) between two strings using Dynamic Programming.

    Args:
        s1 (str): The first input string.
        s2 (str): The second input string.

    Returns:
        int: The length of the longest common subsequence between s1 and s2.
    """

    m, n = len(s1), len(s2)

    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]


# Test cases
if __name__ == "__main__":
    s1 = "abcde"
    s2 = "ace"
    print(f"LCS length of '{s1}' and '{s2}':", longest_common_subsequence(s1, s2))
# Out:
# LCS length of 'abcde' and 'ace': 3

# %%
#Task3: Knapsack Problem
def knapsack(weights, values, capacity):
    """
    Knapsack problem using Dynamic Programming.

    Args:
        weights (list[int]): List of weights of items.
        values (list[int]): List of values of items.
        capacity (int): Maximum weight capacity of the knapsack.

    Returns:
        int: The maximum value that can be achieved without exceeding the weight capacity.
    """

    n = len(weights)

    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:
                dp[i][w] = max(dp[i - 1][w], dp[i - 1][w - weights[i - 1]] + values[i - 1])
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]


# Test cases
if __name__ == "__main__":
    weights = [1, 3, 4, 5]
    values = [1, 4, 5, 7]
    capacity = 7
    print(f"Maximum value for capacity {capacity}:", knapsack(weights, values, capacity))
# Out:
# Maximum value for capacity 7: 9

# %%
#Task 1. Classify Temperatures:
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]
cold=[]
mild=[]
comfortable=[]
for i in range(len(temperatures)-1):
  val=temperatures[i]
  if val<10:
    cold.append(val)
  elif val>=10 and val <15:
    mild.append(val)
  else:
    comfortable.append(val)

print("The cold temperatures are: ", cold)
print("The mild temperatures are: ", mild)
print("The comfortable temperatures are: ", comfortable)
# Out:
# The cold temperatures are:  [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# The mild temperatures are:  [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1]
# The comfortable temperatures are:  [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]

# %%
#Task2 Based on Data
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]
cold=[]
mild=[]
comfortable=[]
for i in range(len(temperatures)-1):
  val=temperatures[i]
  if val<10:
    cold.append(val)
  elif val>=10 and val <15:
    mild.append(val)
  else:
    comfortable.append(val)

print("Number of mild days were: ", len(mild))
print("Number of comfortable days were: ", len(comfortable))
print("Number of cold days were: ", len(cold))
# Out:
# Number of mild days were:  15
# Number of comfortable days were:  16
# Number of cold days were:  16

# %%
#Task3 Convert Temperature from Celsius to Fahrenheit
temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]
temperatures_fahrenheit=[]
for i in range(len(temperatures)-1):
  fahren=(i*9/5)+32
  temperatures_fahrenheit.append(fahren)
print(temperatures_fahrenheit)
# Out:
# [32.0, 33.8, 35.6, 37.4, 39.2, 41.0, 42.8, 44.6, 46.4, 48.2, 50.0, 51.8, 53.6, 55.4, 57.2, 59.0, 60.8, 62.6, 64.4, 66.2, 68.0, 69.8, 71.6, 73.4, 75.2, 77.0, 78.8, 80.6, 82.4, 84.2, 86.0, 87.8, 89.6, 91.4, 93.2, 95.0, 96.8, 98.6, 100.4, 102.2, 104.0, 105.8, 107.6, 109.4, 111.2, 113.0, 114.8]

# %%
#Task4 Analyze Temperature Patterns by Time of Day:
import matplotlib.pyplot as plt

temperatures = [8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]

night= []
day= []
eve= []

for i,temp in enumerate(temperatures):
  if i%3==0:
    night.append(temp)
  elif i%3==1:
    eve.append(temp)
  else:
    day.append(temp)

average_day_temp= sum(day)/len(day)
print(f"The avg. day temperature is {average_day_temp:.2f} degree celcius")


#day vs temperature plot
plt.figure(figsize=(10,6))
plt.plot(range(1, len(day)+1), day, marker='o', linestyle='-', color='red', label='Day Temperatures')
plt.title("Day vs Temperature")
plt.xlabel("Days")
plt.ylabel("Temperature (degree celcius)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# The avg. day temperature is 13.41 degree celcius

# %%
#8.1.1 Excercise- Recursion:
def sum_nested_list(nested_list):
  total=0
  for element in nested_list:
    if isinstance(element, list):
      total += sum_nested_list(element)
    else:
      total+=element
  return total

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
print(sum_nested_list(nested_list))
# Out:
# 36

# %%
#Task2 Genereate all Permutations of a String
def generate_permutations(s):
    if len(s) == 1:
        return [s]

    permutations = set()
    for i, char in enumerate(s):
        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            permutations.add(char + perm)

    return list(permutations)

print(sorted(generate_permutations("abc")))
print(sorted(generate_permutations("aab")))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ['aab', 'aba', 'baa']

# %%
#Task3 Directory Size Calculations
def calculate_directory_size(directory):
  total_size=0
  for key, value in directory.items():
    if isinstance(value, dict):
      total_size += calculate_directory_size(value)
    else:
      total_size += value
  return total_size

sample_directory= {
   "file1.txt": 200,
"file2.txt": 300,
"subdir1": {
"file3.txt": 400,
"file4.txt": 100
},
"subdir2": {
"subsubdir1": {
"file5.txt": 250
},"file6.txt": 150
}
}

print("Total directory size: ", calculate_directory_size(sample_directory), "KB")
# Out:
# Total directory size:  1400 KB
